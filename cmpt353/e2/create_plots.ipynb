# %%
import numpy as np
import pandas as pd
import sys
import matplotlib.pyplot as plt

# %%
filename1 = "pagecounts-20190509-120000.txt"
filename2 = "pagecounts-20190509-130000.txt"

# %%
file1 = pd.read_csv(filename1, sep=' ', header=None, index_col=1,
        names=['lang', 'page', 'views', 'bytes'])
file1
# Out:
#                             lang  views  bytes
# page
# Athol_Moffitt                 en      1      0
# Diction                       en      1      0
# Person-centered_therapy       en     10      0
# Dave_Dobbyn                   en      2      0
# MAZ-7310                      en      5      0
# ...                          ...    ...    ...
# Holderness_Rural_District     en      1      0
# G-mik                         en      4      0
# Little_Go_Beep                en      1      0
# Benoît                        en      2      0
# Saints_Row:_Gat_Out_of_Hell   en      1      0
#
# [2500 rows x 3 columns]

# %%
file1 = file1.sort_values('views',ascending=False)
file1
# Out:
#                                               lang  views  bytes
# page
# Java_(programming_language)                     en    128      0
# Universally_unique_identifier                   en    108      0
# Alex_Ferguson                                   en     72      0
# Citric_acid_cycle                               en     58      0
# Senegal                                         en     53      0
# ...                                            ...    ...    ...
# Paul_Flato                                      en      1      0
# List_of_French_Open_women's_singles_champions   en      1      0
# Yacuma                                          en      1      0
# Steradians                                      en      1      0
# Saints_Row:_Gat_Out_of_Hell                     en      1      0
#
# [2500 rows x 3 columns]

# %%
file2 = pd.read_csv(filename2, sep=' ', header=None, index_col=1,
        names=['lang', 'page', 'views2', 'bytes'])
file2
# Out:
#                                          lang  views2  bytes
# page
# 1949_Grand_Prix_motorcycle_racing_season   en       2      0
# 1951_in_Brazil                             en       1      0
# 1976_Japanese_Grand_Prix                   en       1      0
# 1980_Campeonato_Brasileiro_Série_A         en       1      0
# 1980_NBA_Finals                            en       4      0
# ...                                       ...     ...    ...
# Zingiber_zerumbet                          en       2      0
# Zodiac_(film)                              en      52      0
# Zygomaticofacial_nerve                     en       1      0
# Üsküdar                                    en       5      0
# Ń                                          en       3      0
#
# [1241 rows x 3 columns]

# %%
combined = pd.concat([file1, file2], axis=1)
combined
# Out:
#                                               lang  views  bytes lang  views2  \
# Java_(programming_language)                     en    128      0   en   151.0
# Universally_unique_identifier                   en    108      0   en   134.0
# Alex_Ferguson                                   en     72      0   en    74.0
# Citric_acid_cycle                               en     58      0   en    69.0
# Senegal                                         en     53      0   en    52.0
# ...                                            ...    ...    ...  ...     ...
# Paul_Flato                                      en      1      0  NaN     NaN
# List_of_French_Open_women's_singles_champions   en      1      0   en     2.0
# Yacuma                                          en      1      0  NaN     NaN
# Steradians                                      en      1      0   en     4.0
# Saints_Row:_Gat_Out_of_Hell                     en      1      0   en     1.0
#
#                                                bytes
# Java_(programming_language)                      0.0
# Universally_unique_identifier                    0.0
# Alex_Ferguson                                    0.0
# Citric_acid_cycle                                0.0
# Senegal                                          0.0
# ...                                              ...
# Paul_Flato                                       NaN
# List_of_French_Open_women's_singles_champions    0.0
# Yacuma                                           NaN
# Steradians                                       0.0
# Saints_Row:_Gat_Out_of_Hell                      0.0
#
# [2500 rows x 6 columns]

# %%
plt.figure(figsize=(10, 5)) # change the size to something sensible
plt.subplot(1, 2, 1) # subplots in #1 row, 2 columns, select the first
plt.title("Popularity Distribution")
plt.xlabel("Rank")
plt.ylabel("views")
plt.plot(file1['views'].values) # build plot 1
plt.subplot(1, 2, 2) # ... and then select the second
plt.plot(combined['views'].values, combined['views2'].values,'o', color='blue',ms = 4) # build plot 2
plt.xscale('log')
plt.yscale('log')
plt.title("Daily Correlation")
plt.xlabel("Day 1 views")
plt.ylabel("Day 2 views")
# Out:
# Text(0, 0.5, 'Day 2 views')

# %%
plt.savefig('wikipedia.png')
